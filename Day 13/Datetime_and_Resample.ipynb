# %%
 import pandas as pd
 import numpy as np

# %%
import pandas as pd
import random
from datetime import datetime, timedelta

# ---------- 1. Customers ----------
customer_ids = [f'CUST{100+i}' for i in range(15)]
customers = pd.DataFrame({
    'customer_id': customer_ids,
    'customer_name': [f'Customer_{i}' for i in range(len(customer_ids))],
    'country': random.choices(['USA', 'UK', 'Germany', 'India'], k=len(customer_ids))
})
customers.to_csv("customers.csv", index=False)

# ---------- 2. Products ----------
product_ids = [f'PROD{200+i}' for i in range(10)]
products = pd.DataFrame({
    'product_id': product_ids,
    'product_name': [f'Product_{i}' for i in range(len(product_ids))],
    'price': [random.randint(20, 200) for _ in range(len(product_ids))]
})
products.to_csv("products.csv", index=False)

# ---------- 3. Orders (simulate realistic purchases) ----------
orders = []

def random_date():
    start = datetime(2025, 7, 1)
    end = datetime(2025, 7, 20)
    return (start + timedelta(days=random.randint(0, (end - start).days))).strftime("%Y-%m-%d")

for i in range(60):  # 60 orders to simulate multiple purchases
    customer = random.choice(customer_ids)
    product = random.choice(product_ids)
    order = {
        'order_id': f'ORD{i+1:04}',
        'customer_id': customer,
        'product_id': product,
        'quantity': random.randint(1, 5),
        'order_date': random_date()
    }
    orders.append(order)

orders_df = pd.DataFrame(orders)
orders_df.to_csv("orders.csv", index=False)

# %%
orders = pd.DataFrame(orders)
orders
# Out:
#    order_id customer_id product_id  quantity  order_date
# 0   ORD0001     CUST106    PROD207         3  2025-07-14
# 1   ORD0002     CUST114    PROD206         3  2025-07-20
# 2   ORD0003     CUST112    PROD208         3  2025-07-10
# 3   ORD0004     CUST112    PROD202         1  2025-07-15
# 4   ORD0005     CUST101    PROD204         2  2025-07-08
# 5   ORD0006     CUST109    PROD206         5  2025-07-03
# 6   ORD0007     CUST101    PROD203         2  2025-07-01
# 7   ORD0008     CUST105    PROD203         1  2025-07-08
# 8   ORD0009     CUST103    PROD206         3  2025-07-19
# 9   ORD0010     CUST106    PROD201         4  2025-07-04
# 10  ORD0011     CUST108    PROD208         3  2025-07-13
# 11  ORD0012     CUST111    PROD206         2  2025-07-04
# 12  ORD0013     CUST108    PROD206         4  2025-07-08
# 13  ORD0014     CUST107    PROD200         4  2025-07-19
# 14  ORD0015     CUST109    PROD204         1  2025-07-10
# 15  ORD0016     CUST111    PROD208         2  2025-07-07
# 16  ORD0017     CUST105    PROD203         2  2025-07-06
# 17  ORD0018     CUST102    PROD204         1  2025-07-15
# 18  ORD0019     CUST114    PROD206         2  2025-07-03
# 19  ORD0020     CUST101    PROD209         1  2025-07-09
# 20  ORD0021     CUST104    PROD204         2  2025-07-03
# 21  ORD0022     CUST104    PROD209         2  2025-07-09
# 22  ORD0023     CUST114    PROD202         4  2025-07-13
# 23  ORD0024     CUST101    PROD200         5  2025-07-17
# 24  ORD0025     CUST104    PROD200         2  2025-07-14
# 25  ORD0026     CUST113    PROD204         3  2025-07-11
# 26  ORD0027     CUST111    PROD200         4  2025-07-15
# 27  ORD0028     CUST102    PROD207         1  2025-07-13
# 28  ORD0029     CUST111    PROD200         4  2025-07-10
# 29  ORD0030     CUST114    PROD209         2  2025-07-19
# 30  ORD0031     CUST112    PROD204         3  2025-07-16
# 31  ORD0032     CUST103    PROD206         3  2025-07-03
# 32  ORD0033     CUST110    PROD209         1  2025-07-07
# 33  ORD0034     CUST112    PROD201         3  2025-07-10
# 34  ORD0035     CUST111    PROD209         5  2025-07-16
# 35  ORD0036     CUST102    PROD206         1  2025-07-04
# 36  ORD0037     CUST106    PROD208         1  2025-07-15
# 37  ORD0038     CUST111    PROD200         2  2025-07-04
# 38  ORD0039     CUST104    PROD200         4  2025-07-06
# 39  ORD0040     CUST102    PROD207         4  2025-07-15
# 40  ORD0041     CUST104    PROD209         1  2025-07-14
# 41  ORD0042     CUST112    PROD203         3  2025-07-06
# 42  ORD0043     CUST108    PROD204         4  2025-07-19
# 43  ORD0044     CUST113    PROD203         2  2025-07-08
# 44  ORD0045     CUST105    PROD203         1  2025-07-06
# 45  ORD0046     CUST102    PROD203         3  2025-07-08
# 46  ORD0047     CUST104    PROD200         4  2025-07-20
# 47  ORD0048     CUST104    PROD202         5  2025-07-09
# 48  ORD0049     CUST100    PROD204         2  2025-07-10
# 49  ORD0050     CUST107    PROD204         2  2025-07-01
# 50  ORD0051     CUST109    PROD205         1  2025-07-07
# 51  ORD0052     CUST103    PROD200         3  2025-07-16
# 52  ORD0053     CUST100    PROD209         5  2025-07-13
# 53  ORD0054     CUST114    PROD201         5  2025-07-14
# 54  ORD0055     CUST110    PROD203         4  2025-07-06
# 55  ORD0056     CUST110    PROD207         3  2025-07-13
# 56  ORD0057     CUST114    PROD202         1  2025-07-10
# 57  ORD0058     CUST110    PROD204         1  2025-07-03
# 58  ORD0059     CUST106    PROD201         2  2025-07-09
# 59  ORD0060     CUST111    PROD209         3  2025-07-07

# %%
customers =  pd.DataFrame(customers)
customers
# Out:
#    customer_id customer_name  country
# 0      CUST100    Customer_0       UK
# 1      CUST101    Customer_1      USA
# 2      CUST102    Customer_2       UK
# 3      CUST103    Customer_3      USA
# 4      CUST104    Customer_4       UK
# 5      CUST105    Customer_5       UK
# 6      CUST106    Customer_6       UK
# 7      CUST107    Customer_7       UK
# 8      CUST108    Customer_8      USA
# 9      CUST109    Customer_9      USA
# 10     CUST110   Customer_10  Germany
# 11     CUST111   Customer_11       UK
# 12     CUST112   Customer_12       UK
# 13     CUST113   Customer_13  Germany
# 14     CUST114   Customer_14       UK

# %%
products = pd.DataFrame(products)
products
# Out:
#   product_id product_name  price
# 0    PROD200    Product_0     60
# 1    PROD201    Product_1     43
# 2    PROD202    Product_2     50
# 3    PROD203    Product_3    187
# 4    PROD204    Product_4     82
# 5    PROD205    Product_5    169
# 6    PROD206    Product_6    178
# 7    PROD207    Product_7    190
# 8    PROD208    Product_8    147
# 9    PROD209    Product_9    116

# %%
orders['order_date'] = pd.to_datetime(orders['order_date'])
orders
# Out:
#    order_id customer_id product_id  quantity order_date
# 0   ORD0001     CUST106    PROD207         3 2025-07-14
# 1   ORD0002     CUST114    PROD206         3 2025-07-20
# 2   ORD0003     CUST112    PROD208         3 2025-07-10
# 3   ORD0004     CUST112    PROD202         1 2025-07-15
# 4   ORD0005     CUST101    PROD204         2 2025-07-08
# 5   ORD0006     CUST109    PROD206         5 2025-07-03
# 6   ORD0007     CUST101    PROD203         2 2025-07-01
# 7   ORD0008     CUST105    PROD203         1 2025-07-08
# 8   ORD0009     CUST103    PROD206         3 2025-07-19
# 9   ORD0010     CUST106    PROD201         4 2025-07-04
# 10  ORD0011     CUST108    PROD208         3 2025-07-13
# 11  ORD0012     CUST111    PROD206         2 2025-07-04
# 12  ORD0013     CUST108    PROD206         4 2025-07-08
# 13  ORD0014     CUST107    PROD200         4 2025-07-19
# 14  ORD0015     CUST109    PROD204         1 2025-07-10
# 15  ORD0016     CUST111    PROD208         2 2025-07-07
# 16  ORD0017     CUST105    PROD203         2 2025-07-06
# 17  ORD0018     CUST102    PROD204         1 2025-07-15
# 18  ORD0019     CUST114    PROD206         2 2025-07-03
# 19  ORD0020     CUST101    PROD209         1 2025-07-09
# 20  ORD0021     CUST104    PROD204         2 2025-07-03
# 21  ORD0022     CUST104    PROD209         2 2025-07-09
# 22  ORD0023     CUST114    PROD202         4 2025-07-13
# 23  ORD0024     CUST101    PROD200         5 2025-07-17
# 24  ORD0025     CUST104    PROD200         2 2025-07-14
# 25  ORD0026     CUST113    PROD204         3 2025-07-11
# 26  ORD0027     CUST111    PROD200         4 2025-07-15
# 27  ORD0028     CUST102    PROD207         1 2025-07-13
# 28  ORD0029     CUST111    PROD200         4 2025-07-10
# 29  ORD0030     CUST114    PROD209         2 2025-07-19
# 30  ORD0031     CUST112    PROD204         3 2025-07-16
# 31  ORD0032     CUST103    PROD206         3 2025-07-03
# 32  ORD0033     CUST110    PROD209         1 2025-07-07
# 33  ORD0034     CUST112    PROD201         3 2025-07-10
# 34  ORD0035     CUST111    PROD209         5 2025-07-16
# 35  ORD0036     CUST102    PROD206         1 2025-07-04
# 36  ORD0037     CUST106    PROD208         1 2025-07-15
# 37  ORD0038     CUST111    PROD200         2 2025-07-04
# 38  ORD0039     CUST104    PROD200         4 2025-07-06
# 39  ORD0040     CUST102    PROD207         4 2025-07-15
# 40  ORD0041     CUST104    PROD209         1 2025-07-14
# 41  ORD0042     CUST112    PROD203         3 2025-07-06
# 42  ORD0043     CUST108    PROD204         4 2025-07-19
# 43  ORD0044     CUST113    PROD203         2 2025-07-08
# 44  ORD0045     CUST105    PROD203         1 2025-07-06
# 45  ORD0046     CUST102    PROD203         3 2025-07-08
# 46  ORD0047     CUST104    PROD200         4 2025-07-20
# 47  ORD0048     CUST104    PROD202         5 2025-07-09
# 48  ORD0049     CUST100    PROD204         2 2025-07-10
# 49  ORD0050     CUST107    PROD204         2 2025-07-01
# 50  ORD0051     CUST109    PROD205         1 2025-07-07
# 51  ORD0052     CUST103    PROD200         3 2025-07-16
# 52  ORD0053     CUST100    PROD209         5 2025-07-13
# 53  ORD0054     CUST114    PROD201         5 2025-07-14
# 54  ORD0055     CUST110    PROD203         4 2025-07-06
# 55  ORD0056     CUST110    PROD207         3 2025-07-13
# 56  ORD0057     CUST114    PROD202         1 2025-07-10
# 57  ORD0058     CUST110    PROD204         1 2025-07-03
# 58  ORD0059     CUST106    PROD201         2 2025-07-09
# 59  ORD0060     CUST111    PROD209         3 2025-07-07

# %%
table  = orders.set_index('product_id').join(products.set_index('product_id'), on = 'product_id', how = 'left')
table
# Out:
#            order_id customer_id  quantity order_date product_name  price
# product_id
# PROD207     ORD0001     CUST106         3 2025-07-14    Product_7    190
# PROD206     ORD0002     CUST114         3 2025-07-20    Product_6    178
# PROD208     ORD0003     CUST112         3 2025-07-10    Product_8    147
# PROD202     ORD0004     CUST112         1 2025-07-15    Product_2     50
# PROD204     ORD0005     CUST101         2 2025-07-08    Product_4     82
# PROD206     ORD0006     CUST109         5 2025-07-03    Product_6    178
# PROD203     ORD0007     CUST101         2 2025-07-01    Product_3    187
# PROD203     ORD0008     CUST105         1 2025-07-08    Product_3    187
# PROD206     ORD0009     CUST103         3 2025-07-19    Product_6    178
# PROD201     ORD0010     CUST106         4 2025-07-04    Product_1     43
# PROD208     ORD0011     CUST108         3 2025-07-13    Product_8    147
# PROD206     ORD0012     CUST111         2 2025-07-04    Product_6    178
# PROD206     ORD0013     CUST108         4 2025-07-08    Product_6    178
# PROD200     ORD0014     CUST107         4 2025-07-19    Product_0     60
# PROD204     ORD0015     CUST109         1 2025-07-10    Product_4     82
# PROD208     ORD0016     CUST111         2 2025-07-07    Product_8    147
# PROD203     ORD0017     CUST105         2 2025-07-06    Product_3    187
# PROD204     ORD0018     CUST102         1 2025-07-15    Product_4     82
# PROD206     ORD0019     CUST114         2 2025-07-03    Product_6    178
# PROD209     ORD0020     CUST101         1 2025-07-09    Product_9    116
# PROD204     ORD0021     CUST104         2 2025-07-03    Product_4     82
# PROD209     ORD0022     CUST104         2 2025-07-09    Product_9    116
# PROD202     ORD0023     CUST114         4 2025-07-13    Product_2     50
# PROD200     ORD0024     CUST101         5 2025-07-17    Product_0     60
# PROD200     ORD0025     CUST104         2 2025-07-14    Product_0     60
# PROD204     ORD0026     CUST113         3 2025-07-11    Product_4     82
# PROD200     ORD0027     CUST111         4 2025-07-15    Product_0     60
# PROD207     ORD0028     CUST102         1 2025-07-13    Product_7    190
# PROD200     ORD0029     CUST111         4 2025-07-10    Product_0     60
# PROD209     ORD0030     CUST114         2 2025-07-19    Product_9    116
# PROD204     ORD0031     CUST112         3 2025-07-16    Product_4     82
# PROD206     ORD0032     CUST103         3 2025-07-03    Product_6    178
# PROD209     ORD0033     CUST110         1 2025-07-07    Product_9    116
# PROD201     ORD0034     CUST112         3 2025-07-10    Product_1     43
# PROD209     ORD0035     CUST111         5 2025-07-16    Product_9    116
# PROD206     ORD0036     CUST102         1 2025-07-04    Product_6    178
# PROD208     ORD0037     CUST106         1 2025-07-15    Product_8    147
# PROD200     ORD0038     CUST111         2 2025-07-04    Product_0     60
# PROD200     ORD0039     CUST104         4 2025-07-06    Product_0     60
# PROD207     ORD0040     CUST102         4 2025-07-15    Product_7    190
# PROD209     ORD0041     CUST104         1 2025-07-14    Product_9    116
# PROD203     ORD0042     CUST112         3 2025-07-06    Product_3    187
# PROD204     ORD0043     CUST108         4 2025-07-19    Product_4     82
# PROD203     ORD0044     CUST113         2 2025-07-08    Product_3    187
# PROD203     ORD0045     CUST105         1 2025-07-06    Product_3    187
# PROD203     ORD0046     CUST102         3 2025-07-08    Product_3    187
# PROD200     ORD0047     CUST104         4 2025-07-20    Product_0     60
# PROD202     ORD0048     CUST104         5 2025-07-09    Product_2     50
# PROD204     ORD0049     CUST100         2 2025-07-10    Product_4     82
# PROD204     ORD0050     CUST107         2 2025-07-01    Product_4     82
# PROD205     ORD0051     CUST109         1 2025-07-07    Product_5    169
# PROD200     ORD0052     CUST103         3 2025-07-16    Product_0     60
# PROD209     ORD0053     CUST100         5 2025-07-13    Product_9    116
# PROD201     ORD0054     CUST114         5 2025-07-14    Product_1     43
# PROD203     ORD0055     CUST110         4 2025-07-06    Product_3    187
# PROD207     ORD0056     CUST110         3 2025-07-13    Product_7    190
# PROD202     ORD0057     CUST114         1 2025-07-10    Product_2     50
# PROD204     ORD0058     CUST110         1 2025-07-03    Product_4     82
# PROD201     ORD0059     CUST106         2 2025-07-09    Product_1     43
# PROD209     ORD0060     CUST111         3 2025-07-07    Product_9    116

# %%
table['revenue'] = table['quantity']*table['price']
table
# Out:
#            order_id customer_id  quantity order_date product_name  price  \
# product_id
# PROD207     ORD0001     CUST106         3 2025-07-14    Product_7    190
# PROD206     ORD0002     CUST114         3 2025-07-20    Product_6    178
# PROD208     ORD0003     CUST112         3 2025-07-10    Product_8    147
# PROD202     ORD0004     CUST112         1 2025-07-15    Product_2     50
# PROD204     ORD0005     CUST101         2 2025-07-08    Product_4     82
# PROD206     ORD0006     CUST109         5 2025-07-03    Product_6    178
# PROD203     ORD0007     CUST101         2 2025-07-01    Product_3    187
# PROD203     ORD0008     CUST105         1 2025-07-08    Product_3    187
# PROD206     ORD0009     CUST103         3 2025-07-19    Product_6    178
# PROD201     ORD0010     CUST106         4 2025-07-04    Product_1     43
# PROD208     ORD0011     CUST108         3 2025-07-13    Product_8    147
# PROD206     ORD0012     CUST111         2 2025-07-04    Product_6    178
# PROD206     ORD0013     CUST108         4 2025-07-08    Product_6    178
# PROD200     ORD0014     CUST107         4 2025-07-19    Product_0     60
# PROD204     ORD0015     CUST109         1 2025-07-10    Product_4     82
# PROD208     ORD0016     CUST111         2 2025-07-07    Product_8    147
# PROD203     ORD0017     CUST105         2 2025-07-06    Product_3    187
# PROD204     ORD0018     CUST102         1 2025-07-15    Product_4     82
# PROD206     ORD0019     CUST114         2 2025-07-03    Product_6    178
# PROD209     ORD0020     CUST101         1 2025-07-09    Product_9    116
# PROD204     ORD0021     CUST104         2 2025-07-03    Product_4     82
# PROD209     ORD0022     CUST104         2 2025-07-09    Product_9    116
# PROD202     ORD0023     CUST114         4 2025-07-13    Product_2     50
# PROD200     ORD0024     CUST101         5 2025-07-17    Product_0     60
# PROD200     ORD0025     CUST104         2 2025-07-14    Product_0     60
# PROD204     ORD0026     CUST113         3 2025-07-11    Product_4     82
# PROD200     ORD0027     CUST111         4 2025-07-15    Product_0     60
# PROD207     ORD0028     CUST102         1 2025-07-13    Product_7    190
# PROD200     ORD0029     CUST111         4 2025-07-10    Product_0     60
# PROD209     ORD0030     CUST114         2 2025-07-19    Product_9    116
# PROD204     ORD0031     CUST112         3 2025-07-16    Product_4     82
# PROD206     ORD0032     CUST103         3 2025-07-03    Product_6    178
# PROD209     ORD0033     CUST110         1 2025-07-07    Product_9    116
# PROD201     ORD0034     CUST112         3 2025-07-10    Product_1     43
# PROD209     ORD0035     CUST111         5 2025-07-16    Product_9    116
# PROD206     ORD0036     CUST102         1 2025-07-04    Product_6    178
# PROD208     ORD0037     CUST106         1 2025-07-15    Product_8    147
# PROD200     ORD0038     CUST111         2 2025-07-04    Product_0     60
# PROD200     ORD0039     CUST104         4 2025-07-06    Product_0     60
# PROD207     ORD0040     CUST102         4 2025-07-15    Product_7    190
# PROD209     ORD0041     CUST104         1 2025-07-14    Product_9    116
# PROD203     ORD0042     CUST112         3 2025-07-06    Product_3    187
# PROD204     ORD0043     CUST108         4 2025-07-19    Product_4     82
# PROD203     ORD0044     CUST113         2 2025-07-08    Product_3    187
# PROD203     ORD0045     CUST105         1 2025-07-06    Product_3    187
# PROD203     ORD0046     CUST102         3 2025-07-08    Product_3    187
# PROD200     ORD0047     CUST104         4 2025-07-20    Product_0     60
# PROD202     ORD0048     CUST104         5 2025-07-09    Product_2     50
# PROD204     ORD0049     CUST100         2 2025-07-10    Product_4     82
# PROD204     ORD0050     CUST107         2 2025-07-01    Product_4     82
# PROD205     ORD0051     CUST109         1 2025-07-07    Product_5    169
# PROD200     ORD0052     CUST103         3 2025-07-16    Product_0     60
# PROD209     ORD0053     CUST100         5 2025-07-13    Product_9    116
# PROD201     ORD0054     CUST114         5 2025-07-14    Product_1     43
# PROD203     ORD0055     CUST110         4 2025-07-06    Product_3    187
# PROD207     ORD0056     CUST110         3 2025-07-13    Product_7    190
# PROD202     ORD0057     CUST114         1 2025-07-10    Product_2     50
# PROD204     ORD0058     CUST110         1 2025-07-03    Product_4     82
# PROD201     ORD0059     CUST106         2 2025-07-09    Product_1     43
# PROD209     ORD0060     CUST111         3 2025-07-07    Product_9    116
#
#             revenue
# product_id
# PROD207         570
# PROD206         534
# PROD208         441
# PROD202          50
# PROD204         164
# PROD206         890
# PROD203         374
# PROD203         187
# PROD206         534
# PROD201         172
# PROD208         441
# PROD206         356
# PROD206         712
# PROD200         240
# PROD204          82
# PROD208         294
# PROD203         374
# PROD204          82
# PROD206         356
# PROD209         116
# PROD204         164
# PROD209         232
# PROD202         200
# PROD200         300
# PROD200         120
# PROD204         246
# PROD200         240
# PROD207         190
# PROD200         240
# PROD209         232
# PROD204         246
# PROD206         534
# PROD209         116
# PROD201         129
# PROD209         580
# PROD206         178
# PROD208         147
# PROD200         120
# PROD200         240
# PROD207         760
# PROD209         116
# PROD203         561
# PROD204         328
# PROD203         374
# PROD203         187
# PROD203         561
# PROD200         240
# PROD202         250
# PROD204         164
# PROD204         164
# PROD205         169
# PROD200         180
# PROD209         580
# PROD201         215
# PROD203         748
# PROD207         570
# PROD202          50
# PROD204          82
# PROD201          86
# PROD209         348

# %%
monthly_revenue = table.groupby(table['order_date'].dt.to_period('M'))['revenue'].sum()
monthly_revenue
# Out:
# order_date
# 2025-07    18156
# Freq: M, Name: revenue, dtype: int64

# %%
# calculate the which countrywise customers purchase more

customer_table = orders.set_index('customer_id').join(customers.set_index('customer_id'),on = 'customer_id', how = 'left')
customer_table
# Out:
#             order_id product_id  quantity order_date customer_name  country
# customer_id
# CUST106      ORD0001    PROD207         3 2025-07-14    Customer_6       UK
# CUST114      ORD0002    PROD206         3 2025-07-20   Customer_14       UK
# CUST112      ORD0003    PROD208         3 2025-07-10   Customer_12       UK
# CUST112      ORD0004    PROD202         1 2025-07-15   Customer_12       UK
# CUST101      ORD0005    PROD204         2 2025-07-08    Customer_1      USA
# CUST109      ORD0006    PROD206         5 2025-07-03    Customer_9      USA
# CUST101      ORD0007    PROD203         2 2025-07-01    Customer_1      USA
# CUST105      ORD0008    PROD203         1 2025-07-08    Customer_5       UK
# CUST103      ORD0009    PROD206         3 2025-07-19    Customer_3      USA
# CUST106      ORD0010    PROD201         4 2025-07-04    Customer_6       UK
# CUST108      ORD0011    PROD208         3 2025-07-13    Customer_8      USA
# CUST111      ORD0012    PROD206         2 2025-07-04   Customer_11       UK
# CUST108      ORD0013    PROD206         4 2025-07-08    Customer_8      USA
# CUST107      ORD0014    PROD200         4 2025-07-19    Customer_7       UK
# CUST109      ORD0015    PROD204         1 2025-07-10    Customer_9      USA
# CUST111      ORD0016    PROD208         2 2025-07-07   Customer_11       UK
# CUST105      ORD0017    PROD203         2 2025-07-06    Customer_5       UK
# CUST102      ORD0018    PROD204         1 2025-07-15    Customer_2       UK
# CUST114      ORD0019    PROD206         2 2025-07-03   Customer_14       UK
# CUST101      ORD0020    PROD209         1 2025-07-09    Customer_1      USA
# CUST104      ORD0021    PROD204         2 2025-07-03    Customer_4       UK
# CUST104      ORD0022    PROD209         2 2025-07-09    Customer_4       UK
# CUST114      ORD0023    PROD202         4 2025-07-13   Customer_14       UK
# CUST101      ORD0024    PROD200         5 2025-07-17    Customer_1      USA
# CUST104      ORD0025    PROD200         2 2025-07-14    Customer_4       UK
# CUST113      ORD0026    PROD204         3 2025-07-11   Customer_13  Germany
# CUST111      ORD0027    PROD200         4 2025-07-15   Customer_11       UK
# CUST102      ORD0028    PROD207         1 2025-07-13    Customer_2       UK
# CUST111      ORD0029    PROD200         4 2025-07-10   Customer_11       UK
# CUST114      ORD0030    PROD209         2 2025-07-19   Customer_14       UK
# CUST112      ORD0031    PROD204         3 2025-07-16   Customer_12       UK
# CUST103      ORD0032    PROD206         3 2025-07-03    Customer_3      USA
# CUST110      ORD0033    PROD209         1 2025-07-07   Customer_10  Germany
# CUST112      ORD0034    PROD201         3 2025-07-10   Customer_12       UK
# CUST111      ORD0035    PROD209         5 2025-07-16   Customer_11       UK
# CUST102      ORD0036    PROD206         1 2025-07-04    Customer_2       UK
# CUST106      ORD0037    PROD208         1 2025-07-15    Customer_6       UK
# CUST111      ORD0038    PROD200         2 2025-07-04   Customer_11       UK
# CUST104      ORD0039    PROD200         4 2025-07-06    Customer_4       UK
# CUST102      ORD0040    PROD207         4 2025-07-15    Customer_2       UK
# CUST104      ORD0041    PROD209         1 2025-07-14    Customer_4       UK
# CUST112      ORD0042    PROD203         3 2025-07-06   Customer_12       UK
# CUST108      ORD0043    PROD204         4 2025-07-19    Customer_8      USA
# CUST113      ORD0044    PROD203         2 2025-07-08   Customer_13  Germany
# CUST105      ORD0045    PROD203         1 2025-07-06    Customer_5       UK
# CUST102      ORD0046    PROD203         3 2025-07-08    Customer_2       UK
# CUST104      ORD0047    PROD200         4 2025-07-20    Customer_4       UK
# CUST104      ORD0048    PROD202         5 2025-07-09    Customer_4       UK
# CUST100      ORD0049    PROD204         2 2025-07-10    Customer_0       UK
# CUST107      ORD0050    PROD204         2 2025-07-01    Customer_7       UK
# CUST109      ORD0051    PROD205         1 2025-07-07    Customer_9      USA
# CUST103      ORD0052    PROD200         3 2025-07-16    Customer_3      USA
# CUST100      ORD0053    PROD209         5 2025-07-13    Customer_0       UK
# CUST114      ORD0054    PROD201         5 2025-07-14   Customer_14       UK
# CUST110      ORD0055    PROD203         4 2025-07-06   Customer_10  Germany
# CUST110      ORD0056    PROD207         3 2025-07-13   Customer_10  Germany
# CUST114      ORD0057    PROD202         1 2025-07-10   Customer_14       UK
# CUST110      ORD0058    PROD204         1 2025-07-03   Customer_10  Germany
# CUST106      ORD0059    PROD201         2 2025-07-09    Customer_6       UK
# CUST111      ORD0060    PROD209         3 2025-07-07   Customer_11       UK

# %%
df = customer_table.groupby(['country'])['customer_name'].max()
df
# Out:
# country
# Germany    Customer_13
# UK          Customer_7
# USA         Customer_9
# Name: customer_name, dtype: object

# %%
df = pd.DataFrame({'year': [2015, 2016],
                   'month': [2, 3],
                   'day': [4, 5]})
pd.to_datetime(df)
# Out:
# 0   2015-02-04
# 1   2016-03-05
# dtype: datetime64[ns]

# %%
pd.to_datetime(1490195805, unit='s')
# Out:
# Timestamp('2017-03-22 15:16:45')

# %%
pd.to_datetime([1, 2, 3], unit='D',
               origin=pd.Timestamp('1960-01-01'))
# Out:
# DatetimeIndex(['1960-01-02', '1960-01-03', '1960-01-04'], dtype='datetime64[ns]', freq=None)

# %%
pd.to_datetime('2018-10-26 12:00:00.0000000011',
               format='%Y-%m-%d %H:%M:%S.%f')
# Out:
# Timestamp('2018-10-26 12:00:00.000000001')

# %%
date = pd.to_datetime('12000003',format='%Y%m%d', errors = 'coerce')
date
# Out:
# NaT

# %%
result = pd.to_datetime(['2018-10-26 12:00:00', '2018-10-26 13:00:15'])
result
# Out:
# DatetimeIndex(['2018-10-26 12:00:00', '2018-10-26 13:00:15'], dtype='datetime64[ns]', freq=None)

# %%
from datetime import datetime
pd.to_datetime(["2020-01-01 01:00:00-01:00",
                datetime(2020, 1, 1, 3, 0)])
# Out:
# /tmp/ipython-input-19-1446634411.py:2: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   pd.to_datetime(["2020-01-01 01:00:00-01:00",
# Index([2020-01-01 01:00:00-01:00, 2020-01-01 03:00:00], dtype='object')

# %%
time = pd.to_datetime(['2020-10-25 02:00 +0200','2020-10-25 04:00 +0100'])
print(time)
# Out:
# Index([2020-10-25 02:00:00+02:00, 2020-10-25 04:00:00+01:00], dtype='object')
# /tmp/ipython-input-21-698381786.py:1: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   time = pd.to_datetime(['2020-10-25 02:00 +0200','2020-10-25 04:00 +0100'])

# %%
pd.to_datetime(['2018-10-26 12:00 -0530', '2018-10-26 12:00 -0500'],
               utc=True)
# Out:
# DatetimeIndex(['2018-10-26 17:30:00+00:00', '2018-10-26 17:00:00+00:00'], dtype='datetime64[ns, UTC]', freq=None)

# %%
df = pd.DataFrame({'date_col':['2023-01-15','2024-07-20','2025-03-05']})


df['date_col'] = pd.to_datetime(df['date_col'])


df['year'] = df['date_col'].dt.year
df['month'] = df['date_col'].dt.month
df['year'] = df['date_col'].dt.day

# %%
date = "2010-02-10 14:30:00"
obj = pd.to_datetime(date)
print(obj)
print(type(obj))
# Out:
# 2010-02-10 14:30:00
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
data = ['2010-01-01', '2023-01-02','2024-05-01']
dt = pd.to_datetime(data)
dt
# Out:
# DatetimeIndex(['2010-01-01', '2023-01-02', '2024-05-01'], dtype='datetime64[ns]', freq=None)

# %%
df = pd.DataFrame({'datetime': pd.to_datetime(['2024-07-03 10:00', '2025-08-05 14:00'])})
print(df)

df['year'] = df['datetime'].dt.year
df
# Out:
#              datetime
# 0 2024-07-03 10:00:00
# 1 2025-08-05 14:00:00
#              datetime  year
# 0 2024-07-03 10:00:00  2024
# 1 2025-08-05 14:00:00  2025

# %%
import pandas as pd

# Create a sample DataFrame with a DatetimeIndex
data = {'value': [10, 12, 8, 15, 20, 18, 25, 22]}
dates = pd.to_datetime(['2025-01-01 09:00', '2025-01-01 10:00', '2025-01-01 11:00',
                        '2025-01-02 09:00', '2025-01-02 10:00', '2025-01-02 11:00',
                        '2025-01-03 09:00', '2025-01-03 10:00'])
df = pd.DataFrame(data, index=dates)

df_daily_mean = df.resample('D').mean()
print("Daily Mean:\n", df_daily_mean)



# Upsample from hourly to 30-minute intervals, forward filling missing values
df_30min_ffill = df.resample('30min').ffill()
print("\n30-minute intervals (forward fill):\n", df_30min_ffill)
# Out:
# Daily Mean:
#                  value
# 2025-01-01  10.000000
# 2025-01-02  17.666667
# 2025-01-03  23.500000
#
# 30-minute intervals (forward fill):
#                       value
# 2025-01-01 09:00:00     10
# 2025-01-01 09:30:00     10
# 2025-01-01 10:00:00     12
# 2025-01-01 10:30:00     12
# 2025-01-01 11:00:00      8
# ...                    ...
# 2025-01-03 08:00:00     18
# 2025-01-03 08:30:00     18
# 2025-01-03 09:00:00     25
# 2025-01-03 09:30:00     25
# 2025-01-03 10:00:00     22
#
# [99 rows x 1 columns]

# %%
index = pd.date_range('1/1/2000', periods=9, freq='min')
series = pd.Series(range(9), index=index)
series
# Out:
# 2000-01-01 00:00:00    0
# 2000-01-01 00:01:00    1
# 2000-01-01 00:02:00    2
# 2000-01-01 00:03:00    3
# 2000-01-01 00:04:00    4
# 2000-01-01 00:05:00    5
# 2000-01-01 00:06:00    6
# 2000-01-01 00:07:00    7
# 2000-01-01 00:08:00    8
# Freq: min, dtype: int64

# %%
# Sample time-series data
data = {
    'date': pd.date_range('2023-01-01', periods=10, freq='D'),
    'sales': [200, 220, 250, 230, 210, 300, 280, 270, 260, 240]
}
df = pd.DataFrame(data)
df['date'] = pd.to_datetime(df['date'])

# Resampling sales data to get weekly sums
weekly_sales = df.resample('W', on='date').sum()

print(weekly_sales)
# Out:
#             sales
# date
# 2023-01-01    200
# 2023-01-08   1760
# 2023-01-15    500

# %%
index = pd.date_range('1/07/2025', '30/07/2025')
series = pd.Series(index=index)
series
# Out:
# 2025-01-07   NaN
# 2025-01-08   NaN
# 2025-01-09   NaN
# 2025-01-10   NaN
# 2025-01-11   NaN
#               ..
# 2025-07-26   NaN
# 2025-07-27   NaN
# 2025-07-28   NaN
# 2025-07-29   NaN
# 2025-07-30   NaN
# Freq: D, Length: 205, dtype: float64

# %%
series.resample('3min').sum()
# Out:
# 2025-01-07 00:00:00    0.0
# 2025-01-07 00:03:00    0.0
# 2025-01-07 00:06:00    0.0
# 2025-01-07 00:09:00    0.0
# 2025-01-07 00:12:00    0.0
#                       ...
# 2025-07-29 23:48:00    0.0
# 2025-07-29 23:51:00    0.0
# 2025-07-29 23:54:00    0.0
# 2025-07-29 23:57:00    0.0
# 2025-07-30 00:00:00    0.0
# Freq: 3min, Length: 97921, dtype: float64

# %%
series.resample('3min', label='right', closed='right').sum()
# Out:
# 2025-01-07 00:00:00    0.0
# 2025-01-07 00:03:00    0.0
# 2025-01-07 00:06:00    0.0
# 2025-01-07 00:09:00    0.0
# 2025-01-07 00:12:00    0.0
#                       ...
# 2025-07-29 23:48:00    0.0
# 2025-07-29 23:51:00    0.0
# 2025-07-29 23:54:00    0.0
# 2025-07-29 23:57:00    0.0
# 2025-07-30 00:00:00    0.0
# Freq: 3min, Length: 97921, dtype: float64

# %%
series.resample('30s').asfreq()[0:5]
# Out:
# 2025-01-07 00:00:00   NaN
# 2025-01-07 00:00:30   NaN
# 2025-01-07 00:01:00   NaN
# 2025-01-07 00:01:30   NaN
# 2025-01-07 00:02:00   NaN
# Freq: 30s, dtype: float64

# %%
series.resample('3min').sum()
# Out:
# 2025-01-07 00:00:00    0.0
# 2025-01-07 00:03:00    0.0
# 2025-01-07 00:06:00    0.0
# 2025-01-07 00:09:00    0.0
# 2025-01-07 00:12:00    0.0
#                       ...
# 2025-07-29 23:48:00    0.0
# 2025-07-29 23:51:00    0.0
# 2025-07-29 23:54:00    0.0
# 2025-07-29 23:57:00    0.0
# 2025-07-30 00:00:00    0.0
# Freq: 3min, Length: 97921, dtype: float64

# %%
series.resample('3min', label ='left').sum()
# Out:
# 2025-01-07 00:00:00    0.0
# 2025-01-07 00:03:00    0.0
# 2025-01-07 00:06:00    0.0
# 2025-01-07 00:09:00    0.0
# 2025-01-07 00:12:00    0.0
#                       ...
# 2025-07-29 23:48:00    0.0
# 2025-07-29 23:51:00    0.0
# 2025-07-29 23:54:00    0.0
# 2025-07-29 23:57:00    0.0
# 2025-07-30 00:00:00    0.0
# Freq: 3min, Length: 97921, dtype: float64

# %%
def custom_resampler(arraylike):
    return np.sum(arraylike) + 5

series.resample('3min').apply(custom_resampler)
# Out:
# 2025-01-07 00:00:00    5.0
# 2025-01-07 00:03:00    5.0
# 2025-01-07 00:06:00    5.0
# 2025-01-07 00:09:00    5.0
# 2025-01-07 00:12:00    5.0
#                       ...
# 2025-07-29 23:48:00    5.0
# 2025-07-29 23:51:00    5.0
# 2025-07-29 23:54:00    5.0
# 2025-07-29 23:57:00    5.0
# 2025-07-30 00:00:00    5.0
# Freq: 3min, Length: 97921, dtype: float64

# %%
days = pd.date_range('2025-03-20',periods=30,)
# Out:
#                       price  volume
# 2000-01-01 morning       10      50
#            afternoon     11      60
# 2000-01-02 morning        9      40
#            afternoon     13     100
# 2000-01-03 morning       14      50
#            afternoon     18     100
# 2000-01-04 morning       17      40
#            afternoon     19      50

# %%
days = pd.date_range('1/1/2000', periods=4, freq='D')
d2 = {'price': [10, 11, 9, 13, 14, 18, 17, 19],
      'volume': [50, 60, 40, 100, 50, 100, 40, 50]}
df2 = pd.DataFrame(
    d2,
    index=pd.MultiIndex.from_product(
        [days, ['morning', 'afternoon']]
    )
)
df2
# Out:
#                       price  volume
# 2000-01-01 morning       10      50
#            afternoon     11      60
# 2000-01-02 morning        9      40
#            afternoon     13     100
# 2000-01-03 morning       14      50
#            afternoon     18     100
# 2000-01-04 morning       17      40
#            afternoon     19      50

# %%
start, end = '2000-10-01 23:30:00', '2000-10-02 00:30:00'
rng = pd.date_range(start, end, freq='7min')
ts = pd.Series(np.arange(len(rng)) * 3, index=rng)
ts
# Out:
# 2000-10-01 23:30:00     0
# 2000-10-01 23:37:00     3
# 2000-10-01 23:44:00     6
# 2000-10-01 23:51:00     9
# 2000-10-01 23:58:00    12
# 2000-10-02 00:05:00    15
# 2000-10-02 00:12:00    18
# 2000-10-02 00:19:00    21
# 2000-10-02 00:26:00    24
# Freq: 7min, dtype: int64

# %%
ts.resample('17min', origin='2000-01-01').sum()
# Out:
# 2000-10-01 23:24:00     3
# 2000-10-01 23:41:00    15
# 2000-10-01 23:58:00    45
# 2000-10-02 00:15:00    45
# Freq: 17min, dtype: int64

# %%
ts.resample('17min', origin='start').sum()

# %%
ts.resample('17min', offset='23h30min').sum()
# Out:
# 2000-10-01 23:30:00     9
# 2000-10-01 23:47:00    21
# 2000-10-02 00:04:00    54
# 2000-10-02 00:21:00    24
# Freq: 17min, dtype: int64

# %%
ts.resample('17min', origin='end').sum()
# Out:
# 2000-10-01 23:35:00     0
# 2000-10-01 23:52:00    18
# 2000-10-02 00:09:00    27
# 2000-10-02 00:26:00    63
# Freq: 17min, dtype: int64

# %%
import pandas as pd
import datetime as dt

# Create a sample DataFrame with a DatetimeIndex
dates = pd.to_datetime(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05'])
data = {'Value': [10, 20, 15, 25, 30]}
df1 = pd.DataFrame(data, index=dates)



# Slice by a specific date range (inclusive of start and end)
df_range = df1['2023-01-02':'2023-01-04']

# Slice using datetime objects
start_date = dt.datetime(2023, 1, 3)
end_date = dt.datetime(2023, 1, 5)
df_datetime_range = df1[start_date:end_date]

print(df_datetime_range)
# Out:
#             Value
# 2023-01-03     15
# 2023-01-04     25
# 2023-01-05     30

# %%
import pandas as pd

# Create a sample DataFrame with a DatetimeIndex
dates = pd.date_range(start='2020-01-01', end='2022-12-31', freq='D')
df = pd.DataFrame({'value': range(len(dates))}, index=dates)

# Slice for a specific year (e.g., 2021)
df_2021 = df['2021']
print(df_2021.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2021'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-118-2885064879.py in <cell line: 0>()
#       6
#       7 # Slice for a specific year (e.g., 2021)
# ----> 8 df_2021 = df['2021']
#       9 print(df_2021.head())
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: '2021'

# %%
original_df = pd.DataFrame(
    {"foo": range(5), "bar": range(5, 10)}
   )
original_df
# Out:
#    foo  bar
# 0    0    5
# 1    1    6
# 2    2    7
# 3    3    8
# 4    4    9

# %%
df_parquet_bytes = original_df.to_parquet()
from io import BytesIO
restored_df = pd.read_parquet(BytesIO(df_parquet_bytes))
restored_df
# Out:
#    foo  bar
# 0    0    5
# 1    1    6
# 2    2    7
# 3    3    8
# 4    4    9

# %%
# Exercise 18:
# ● Parse date column as datetime.
# ● Resample data to weekly aggregates.
# ● Calculate % change week over week.

date = { 'values':[20,10,15,14,18,23,22,40]}
dates = pd.to_datetime(['2025-01-01 09:00', '2025-01-01 10:00', '2025-01-01 11:00',
                        '2025-01-02 09:00', '2025-01-02 10:00', '2025-01-02 11:00',
                        '2025-01-03 09:00', '2025-01-03 10:00'])


df = pd.DataFrame(data)

# %%
df['date'] = pd.to_datetime(dates)
df['date']
# Out:
# 0   2025-01-01 09:00:00
# 1   2025-01-01 10:00:00
# 2   2025-01-01 11:00:00
# 3   2025-01-02 09:00:00
# 4   2025-01-02 10:00:00
# 5   2025-01-02 11:00:00
# 6   2025-01-03 09:00:00
# 7   2025-01-03 10:00:00
# Name: date, dtype: datetime64[ns]

# %%
df.set_index('date',inplace=True)
weekly = df.resample("W").sum()
weekly
# Out:
#             values
# date
# 2025-01-05     162

# %%
  weekly_percent_change = weekly.pct_change()
  weekly_percent_change
# Out:
#             values
# date
# 2025-01-05     NaN

# %%
import pandas as pd
import numpy as np
import random
from datetime import datetime, timedelta

# Set random seed for reproducibility
random.seed(42)
np.random.seed(42)

# Generate 150 random dates
start_date = datetime(2023, 1, 1)
date_list = [start_date + timedelta(days=i) for i in range(150)]
random_dates = random.choices(date_list, k=150)

# --- WEATHER DATASET ---
weather_data = {
    'date': [d.strftime('%Y-%m-%d') if i % 10 != 0 else d.strftime('%d/%m/%Y') for i, d in enumerate(random_dates)],
    'Temp': [round(np.random.uniform(15, 40), 1) if i % 8 != 0 else 'hot' for i in range(150)],
    'humidity(%)': [np.random.randint(20, 100) if i % 7 != 0 else np.nan for i in range(150)],
    'wind_speed': [round(np.random.uniform(0, 20), 2) if i % 5 != 0 else "fast" for i in range(150)],
    'city': [random.choice(['New York', 'Los Angeles', 'Chicago', np.nan, '']) for _ in range(150)],
}

weather_df = pd.DataFrame(weather_data)

# Add some duplicate rows
weather_df = pd.concat([weather_df, weather_df.iloc[0:5]], ignore_index=True)

# --- SALES DATASET ---
sales_data = {
    'date': [d.strftime('%Y-%m-%d') if i % 6 != 0 else d.strftime('%B %d, %Y') for i, d in enumerate(random_dates)],
    'sales_amount': [round(np.random.uniform(1000, 10000), 2) if i % 10 != 0 else 'high' for i in range(150)],
    'product_id': [random.choice(['P001', 'P002', 'P003', np.nan, 'p001']) for _ in range(150)],
    'units_sold': [np.random.randint(1, 50) if i % 9 != 0 else None for i in range(150)],
    'store_location': [random.choice(['New York', 'Chicago', 'Houston', '', np.nan]) for _ in range(150)],
}

sales_df = pd.DataFrame(sales_data)

# Add some duplicate rows
sales_df = pd.concat([sales_df, sales_df.iloc[2:4]], ignore_index=True)

# --- SAVE TO CSV FILES ---
weather_df.to_csv("weather.csv", index=False)
sales_df.to_csv("sales.csv", index=False)

print("Generated messy 'weather.csv' and 'sales.csv' with 150+ rows each.")
# Out:
# Generated messy 'weather.csv' and 'sales.csv' with 150+ rows each.

# %%
weather_data = pd.read_csv('/content/weather.csv')
sales_data  = pd.read_csv('/content/sales.csv')
# Out:
#                date sales_amount product_id  units_sold store_location
# 0    April 06, 2023         high       P003         NaN            NaN
# 1        2023-01-04      6727.63       P003        28.0            NaN
# 2        2023-02-11      8208.54       P002        36.0       New York
# 3        2023-02-03      7094.52        NaN        26.0        Houston
# 4        2023-04-21       6160.3       p001         8.0        Houston
# ..              ...          ...        ...         ...            ...
# 147      2023-04-20       4550.7       p001        34.0        Houston
# 148      2023-01-31       1960.8       p001         6.0        Houston
# 149      2023-02-16      4020.94       P003         2.0            NaN
# 150      2023-02-11      8208.54       P002        36.0       New York
# 151      2023-02-03      7094.52        NaN        26.0        Houston
#
# [152 rows x 5 columns]

# %%
weather_data.describe()
# Out:
#        humidity(%)
# count   132.000000
# mean     57.250000
# std      22.514584
# min      20.000000
# 25%      39.000000
# 50%      56.000000
# 75%      75.250000
# max      99.000000

# %%
weather_data.shape
# Out:
# (155, 5)

# %%
sales_data.shape
# Out:
# (152, 5)

# %%
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         155 non-null    object
#  1   Temp         155 non-null    object
#  2   humidity(%)  132 non-null    float64
#  3   wind_speed   155 non-null    object
#  4   city         92 non-null     object
# dtypes: float64(1), object(4)
# memory usage: 6.2+ KB

# %%
weather_data.isnull().sum()
# Out:
# date            0
# Temp            0
# humidity(%)    23
# wind_speed      0
# city           63
# dtype: int64

# %%
weather_data.fillna(method='ffill',inplace=True)
weather_data
# Out:
# /tmp/ipython-input-197-764497835.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   weather_data.fillna(method='ffill',inplace=True)
#            date  Temp  humidity(%) wind_speed      city
# 0    06/04/2023   hot          NaN       fast   Chicago
# 1    2023-01-04  24.4         56.0      15.37   Chicago
# 2    2023-02-11  38.8         70.0       0.87   Chicago
# 3    2023-02-03  33.3         63.0      19.89   Chicago
# 4    2023-04-21  30.0         43.0        9.4  New York
# ..          ...   ...          ...        ...       ...
# 150  06/04/2023   hot         54.0       fast   Chicago
# 151  2023-01-04  24.4         56.0      15.37   Chicago
# 152  2023-02-11  38.8         70.0       0.87   Chicago
# 153  2023-02-03  33.3         63.0      19.89   Chicago
# 154  2023-04-21  30.0         43.0        9.4  New York
#
# [155 rows x 5 columns]

# %%
weather_data.isna().sum()
# Out:
# date           0
# Temp           0
# humidity(%)    1
# wind_speed     0
# city           0
# dtype: int64

# %%
df_cleaned = weather_data.dropna(subset=['humidity(%)'])
print(df_cleaned)
# Out:
#            date  Temp  humidity(%) wind_speed         city
# 1    2023-01-04  24.4         56.0      15.37      Chicago
# 2    2023-02-11  38.8         70.0       0.87      Chicago
# 3    2023-02-03  33.3         63.0      19.89      Chicago
# 4    2023-04-21  30.0         43.0        9.4     New York
# 5    2023-04-12  18.9         98.0       fast  Los Angeles
# ..          ...   ...          ...        ...          ...
# 150  06/04/2023   hot         54.0       fast      Chicago
# 151  2023-01-04  24.4         56.0      15.37      Chicago
# 152  2023-02-11  38.8         70.0       0.87      Chicago
# 153  2023-02-03  33.3         63.0      19.89      Chicago
# 154  2023-04-21  30.0         43.0        9.4     New York
#
# [154 rows x 5 columns]

# %%
value_to_drop = 'Na'
column_to_check = 'City'

# Get the indices of rows where the 'City' column contains 'New York'
indices_to_drop = df[df[column_to_check] == value_to_drop].index

# Drop the rows using their indices
df_cleaned = df.drop(indices_to_drop)

print(df_cleaned)

# %%
df_cleaned
# Out:
# (154, 5)

# %%
sales_data.isna().sum()
# Out:
# date               0
# sales_amount       0
# product_id        24
# units_sold        17
# store_location    74
# dtype: int64

# %%
sales_data.fillna(method='ffill',inplace=True)
sales_data
# Out:
# /tmp/ipython-input-210-434743152.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   sales_data.fillna(method='ffill',inplace=True)
#                date sales_amount product_id  units_sold store_location
# 0    April 06, 2023         high       P003         NaN            NaN
# 1        2023-01-04      6727.63       P003        28.0            NaN
# 2        2023-02-11      8208.54       P002        36.0       New York
# 3        2023-02-03      7094.52       P002        26.0        Houston
# 4        2023-04-21       6160.3       p001         8.0        Houston
# ..              ...          ...        ...         ...            ...
# 147      2023-04-20       4550.7       p001        34.0        Houston
# 148      2023-01-31       1960.8       p001         6.0        Houston
# 149      2023-02-16      4020.94       P003         2.0        Houston
# 150      2023-02-11      8208.54       P002        36.0       New York
# 151      2023-02-03      7094.52       P002        26.0        Houston
#
# [152 rows x 5 columns]
