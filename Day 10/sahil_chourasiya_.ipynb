# %%
import numpy as np
import pandas as pd

# %%
Fake_data = pd.read_json("/content/fake_property_data.json")
Fake_data
# Out:
#                                          Property_Title  \
# 0     875 Davis Overpass Suite 394, South Kathrynsid...
# 1     1159 Johnson Pass Apt. 567, South Jamesfurt, M...
# 2     9082 Anna Villages Apt. 511, Port Juanshire, V...
# 3     86578 Lawson Park Suite 865, South Brianfurt, ...
# 4          309 Roy Brook Apt. 282, Lake Scott, FL 84478
# ...                                                 ...
# 9995           139 Fisher Spur, North Brandon, WA 23114
# 9996       275 Gutierrez Views, Lake Victoria, WY 63275
# 9997        341 Vanessa Harbor, North Melissa, CT 39313
# 9998  78647 Brittany Village, North Ethanborough, NY...
# 9999  5461 Nichols Throughway, East Crystalborough, ...
#
#                                                 Address Reviewed_Status  \
# 0     875 Davis Overpass Suite 394, South Kathrynsid...
# 1     1159 Johnson Pass Apt. 567, South Jamesfurt, M...        Reviewed
# 2     9082 Anna Villages Apt. 511, Port Juanshire, V...            Null
# ...

# %%
Field_data = pd.read_excel('/content/Field Config.xlsx')
Field_data
# Out:
#                Column Name Target Table
# 0           Property_Title     property
# 1                  Address     property
# 2          Reviewed_Status        Leads
# 3       Most_Recent_Status        Leads
# 4                   Source        Leads
# ..                     ...          ...
# 61          Selling_Reason        leads
# 62  Seller_Retained_Broker        leads
# 63                HOA_Flag          HOA
# 64          Final_Reviewer        leads
# 65          School_Average     property
#
# [66 rows x 2 columns]

# %%
Fake_data.shape
# Out:
# (10000, 45)

# %%
Field_data.shape
# Out:
# (66, 2)

# %%
Fake_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 45 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Property_Title          10000 non-null  object
#  1   Address                 10000 non-null  object
#  2   Reviewed_Status         10000 non-null  object
#  3   Most_Recent_Status      10000 non-null  object
#  4   Source                  10000 non-null  object
#  5   Market                  10000 non-null  object
#  6   Occupancy               6718 non-null   object
#  7   Flood                   6591 non-null   object
#  8   Street_Address          10000 non-null  object
#  9   City                    10000 non-null  object
#  10  State                   10000 non-null  object
#  11  Zip                     10000 non-null  int64
#  12  Property_Type           10000 non-null  object
#  13  Highway                 6602 non-null   object
# ...

# %%
Field_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Column Name   66 non-null     object
#  1   Target Table  66 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
Field_data.columns
# Out:
# Index(['Column Name', 'Target Table'], dtype='object')

# %%
Fake_data.columns
# Out:
# Index(['Property_Title', 'Address', 'Reviewed_Status', 'Most_Recent_Status',
#        'Source', 'Market', 'Occupancy', 'Flood', 'Street_Address', 'City',
#        'State', 'Zip', 'Property_Type', 'Highway', 'Train', 'Tax_Rate',
#        'SQFT_Basement', 'HTW', 'Pool', 'Commercial', 'Water', 'Sewage',
#        'Year_Built', 'SQFT_MU', 'SQFT_Total', 'Parking', 'Bed', 'Bath',
#        'BasementYesNo', 'Layout', 'Net_Yield', 'IRR', 'Rent_Restricted',
#        'Neighborhood_Rating', 'Latitude', 'Longitude', 'Subdivision', 'Taxes',
#        'Selling_Reason', 'Seller_Retained_Broker', 'Final_Reviewer',
#        'School_Average', 'Valuation', 'HOA', 'Rehab'],
#       dtype='object')

# %%
Fake_data.isnull().sum()
# Out:
# Property_Title               0
# Address                      0
# Reviewed_Status              0
# Most_Recent_Status           0
# Source                       0
# Market                       0
# Occupancy                 3282
# Flood                     3409
# Street_Address               0
# City                         0
# State                        0
# Zip                          0
# Property_Type                0
# Highway                   3398
# Train                     3331
# Tax_Rate                     0
# SQFT_Basement                0
# HTW                       3401
# Pool                      3415
# Commercial                3284
# Water                     3303
# Sewage                    3252
# Year_Built                   0
# SQFT_MU                      0
# SQFT_Total                   0
# Parking                   2489
# Bed                          0
# Bath                         0
# BasementYesNo             3365
# Layout                    2554
# ...

# %%
Field_data.isnull().sum()
# Out:
# Column Name     0
# Target Table    0
# dtype: int64

# %%
numeric_columns= Fake_data.select_dtypes(include =np.number)
numeric_columns
# Out:
#         Zip  Tax_Rate  SQFT_Basement  Year_Built  SQFT_MU  SQFT_Total  Bed  \
# 0     35116      2.95            367        1921     1110        5649    2
# 1     60391      1.75            284        1995     1184        5119    2
# 2     22393      2.19            283        1952     2492        7606    5
# 3     90366      3.39           1927        1937     2586        4822    1
# 4     84478      2.20           1904        1991     1200        9191    5
# ...     ...       ...            ...         ...      ...         ...  ...
# 9995  23114      3.34            773        2014     2558        6372    4
# 9996  63275      3.18           1440        2001     2177        5690    2
# 9997  39313      2.94           1900        2003     1079        8538    2
# 9998  21362      1.28            570        2006      599        6561    1
# 9999   8497      3.39           1981        1956     1544        7343    4
#
# ...

# %%
numeric_columns.count()
# Out:
# Zip                    10000
# Tax_Rate               10000
# SQFT_Basement          10000
# Year_Built             10000
# SQFT_MU                10000
# SQFT_Total             10000
# Bed                    10000
# Bath                   10000
# Net_Yield              10000
# IRR                    10000
# Neighborhood_Rating    10000
# Latitude               10000
# Longitude              10000
# Taxes                  10000
# School_Average         10000
# dtype: int64

# %%
Fake_data['Flood']
# Out:
# 0                None
# 1       Minimal Flood
# 2          Flood Zone
# 3          Flood Zone
# 4          Flood Zone
#             ...
# 9995             None
# 9996       Flood Zone
# 9997       Flood Zone
# 9998    Minimal Flood
# 9999       Flood Zone
# Name: Flood, Length: 10000, dtype: object

# %%
Fake_data['Flood'].fillna('Unknown')
Fake_data['Water'].fillna(Fake_data['Water'].mode()[0])
# Out:
# 0       Well
# 1       City
# 2       City
# 3       City
# 4       City
#         ...
# 9995    Well
# 9996    City
# 9997    Well
# 9998    City
# 9999    Well
# Name: Water, Length: 10000, dtype: object

# %%
Fake_data['SQFT_Total'].fillna(Fake_data['SQFT_Total'].median())
# Out:
# 0       5649
# 1       5119
# 2       7606
# 3       4822
# 4       9191
#         ...
# 9995    6372
# 9996    5690
# 9997    8538
# 9998    6561
# 9999    7343
# Name: SQFT_Total, Length: 10000, dtype: int64

# %%
Fake_data['SQFT_Total'].fillna(Fake_data['SQFT_Total'].median())
# Out:
# 0       5649
# 1       5119
# 2       7606
# 3       4822
# 4       9191
#         ...
# 9995    6372
# 9996    5690
# 9997    8538
# 9998    6561
# 9999    7343
# Name: SQFT_Total, Length: 10000, dtype: int64

# %%
Fake_data['SQFT_Total'].fillna(Fake_data['SQFT_Total'].mode())
# Out:
# 0       5649
# 1       5119
# 2       7606
# 3       4822
# 4       9191
#         ...
# 9995    6372
# 9996    5690
# 9997    8538
# 9998    6561
# 9999    7343
# Name: SQFT_Total, Length: 10000, dtype: int64

# %%
Fake_data['Occupancy'] = Fake_data['Occupancy'].fillna(method = 'ffill')
# Out:
# /tmp/ipython-input-752682991.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Fake_data['Occupancy'] = Fake_data['Occupancy'].fillna(method = 'ffill')

# %%
Fake_data.isnull().sum()
# Out:
# Property_Title               0
# Address                      0
# Reviewed_Status              0
# Most_Recent_Status           0
# Source                       0
# Market                       0
# Occupancy                    2
# Flood                     3409
# Street_Address               0
# City                         0
# State                        0
# Zip                          0
# Property_Type                0
# Highway                   3398
# Train                     3331
# Tax_Rate                     0
# SQFT_Basement                0
# HTW                       3401
# Pool                      3415
# Commercial                3284
# Water                     3303
# Sewage                    3252
# Year_Built                   0
# SQFT_MU                      0
# SQFT_Total                   0
# Parking                   2489
# Bed                          0
# Bath                         0
# BasementYesNo             3365
# Layout                    2554
# ...

# %%
Fake_data = Fake_data.ffill()

cols_to_ffill = [
    "Highway", "Train", "Tax_Rate", "SQFT_Basement", "HTW", "Pool", "Commercial",
    "Water", "Sewage", "Year_Built", "SQFT_MU", "SQFT_Total", "Parking", "Bed", "Bath",
    "BasementYesNo", "Layout", "Net_Yield", "IRR", "Rent_Restricted",
    "Neighborhood_Rating", "Latitude", "Longitude", "Subdivision", "Taxes",
    "Selling_Reason", "Seller_Retained_Broker", "Final_Reviewer", "School_Average",
    "Valuation", "HOA", "Rehab"
]

Fake_data[cols_to_ffill] = Fake_data[cols_to_ffill].ffill()

# %%
Fake_data.isnull().sum()
# Out:
# Property_Title            0
# Address                   0
# Reviewed_Status           0
# Most_Recent_Status        0
# Source                    0
# Market                    0
# Occupancy                 2
# Flood                     1
# Street_Address            0
# City                      0
# State                     0
# Zip                       0
# Property_Type             0
# Highway                   0
# Train                     1
# Tax_Rate                  0
# SQFT_Basement             0
# HTW                       0
# Pool                      0
# Commercial                0
# Water                     0
# Sewage                    0
# Year_Built                0
# SQFT_MU                   0
# SQFT_Total                0
# Parking                   0
# Bed                       0
# Bath                      0
# BasementYesNo             2
# Layout                    0
# Net_Yield                 0
# IRR                       0
# Rent_Restricted           0
# ...

# %%
print(Fake_data['Train'])
# Out:
# 0       None
# 1        Far
# 2       Near
# 3        Far
# 4       Near
#         ...
# 9995    Near
# 9996    Near
# 9997    Near
# 9998    Near
# 9999     Far
# Name: Train, Length: 10000, dtype: object

# %%
Fake_data['Train'] = Fake_data['Train'].fillna('Near')

# %%
Fake_data.isnull().sum()
# Out:
# Property_Title            0
# Address                   0
# Reviewed_Status           0
# Most_Recent_Status        0
# Source                    0
# Market                    0
# Occupancy                 2
# Flood                     1
# Street_Address            0
# City                      0
# State                     0
# Zip                       0
# Property_Type             0
# Highway                   0
# Train                     0
# Tax_Rate                  0
# SQFT_Basement             0
# HTW                       0
# Pool                      0
# Commercial                0
# Water                     0
# Sewage                    0
# Year_Built                0
# SQFT_MU                   0
# SQFT_Total                0
# Parking                   0
# Bed                       0
# Bath                      0
# BasementYesNo             2
# Layout                    0
# Net_Yield                 0
# IRR                       0
# Rent_Restricted           0
# ...

# %%
print(Fake_data['Seller_Retained_Broker'])
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4        Yes
#         ...
# 9995     Yes
# 9996     Yes
# 9997     Yes
# 9998      No
# 9999     Yes
# Name: Seller_Retained_Broker, Length: 10000, dtype: object

# %%
Fake_data['Seller_Retained_Broker	'] = Fake_data['Seller_Retained_Broker'].fillna('yes')

# %%
Fake_data.isnull().sum()
# Out:
# Property_Title              0
# Address                     0
# Reviewed_Status             0
# Most_Recent_Status          0
# Source                      0
# Market                      0
# Occupancy                   2
# Flood                       1
# Street_Address              0
# City                        0
# State                       0
# Zip                         0
# Property_Type               0
# Highway                     0
# Train                       0
# Tax_Rate                    0
# SQFT_Basement               0
# HTW                         0
# Pool                        0
# Commercial                  0
# Water                       0
# Sewage                      0
# Year_Built                  0
# SQFT_MU                     0
# SQFT_Total                  0
# Parking                     0
# Bed                         0
# Bath                        0
# BasementYesNo               2
# Layout                      0
# Net_Yield                   0
# ...

# %%
print(Fake_data['Occupancy'])
# Out:
# 0       None
# 1       None
# 2         No
# 3         No
# 4         No
#         ...
# 9995      No
# 9996     Yes
# 9997     Yes
# 9998     Yes
# 9999     Yes
# Name: Occupancy, Length: 10000, dtype: object

# %%
Fake_data['Occupancy'] = Fake_data['Occupancy'].fillna('Yes')
Fake_data['Seller_Retained_Broker	'] = Fake_data['Seller_Retained_Broker'].fillna('Yes', inplace = True)
Fake_data['BasementYesNo']= Fake_data['BasementYesNo'].fillna('Yes')
# Out:
# /tmp/ipython-input-1776341052.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Fake_data['Seller_Retained_Broker	'] = Fake_data['Seller_Retained_Broker'].fillna('Yes', inplace = True)

# %%
Fake_data.isnull().sum()
# Out:
# Property_Title                  0
# Address                         0
# Reviewed_Status                 0
# Most_Recent_Status              0
# Source                          0
# Market                          0
# Occupancy                       0
# Flood                           1
# Street_Address                  0
# City                            0
# State                           0
# Zip                             0
# Property_Type                   0
# Highway                         0
# Train                           0
# Tax_Rate                        0
# SQFT_Basement                   0
# HTW                             0
# Pool                            0
# Commercial                      0
# Water                           0
# Sewage                          0
# Year_Built                      0
# SQFT_MU                         0
# SQFT_Total                      0
# Parking                         0
# Bed                             0
# ...

# %%
Fake_data['Seller_Retained_Broker\t']= Fake_data['Seller_Retained_Broker\t'].fillna('Yes')

# %%
Fake_data.isnull().sum()
# Out:
# Property_Title              0
# Address                     0
# Reviewed_Status             0
# Most_Recent_Status          0
# Source                      0
# Market                      0
# Occupancy                   0
# Flood                       1
# Street_Address              0
# City                        0
# State                       0
# Zip                         0
# Property_Type               0
# Highway                     0
# Train                       0
# Tax_Rate                    0
# SQFT_Basement               0
# HTW                         0
# Pool                        0
# Commercial                  0
# Water                       0
# Sewage                      0
# Year_Built                  0
# SQFT_MU                     0
# SQFT_Total                  0
# Parking                     0
# Bed                         0
# Bath                        0
# BasementYesNo               0
# Layout                      0
# Net_Yield                   0
# ...

# %%
Fake_data.columns
# Out:
# Index(['Property_Title', 'Address', 'Reviewed_Status', 'Most_Recent_Status',
#        'Source', 'Market', 'Occupancy', 'Flood', 'Street_Address', 'City',
#        'State', 'Zip', 'Property_Type', 'Highway', 'Train', 'Tax_Rate',
#        'SQFT_Basement', 'HTW', 'Pool', 'Commercial', 'Water', 'Sewage',
#        'Year_Built', 'SQFT_MU', 'SQFT_Total', 'Parking', 'Bed', 'Bath',
#        'BasementYesNo', 'Layout', 'Net_Yield', 'IRR', 'Rent_Restricted',
#        'Neighborhood_Rating', 'Latitude', 'Longitude', 'Subdivision', 'Taxes',
#        'Selling_Reason', 'Seller_Retained_Broker', 'Final_Reviewer',
#        'School_Average', 'Valuation', 'HOA', 'Rehab',
#        'Seller_Retained_Broker\t'],
#       dtype='object')

# %%
Fake_data.isnull().sum().head(5)
# Out:
# Property_Title        0
# Address               0
# Reviewed_Status       0
# Most_Recent_Status    0
# Source                0
# dtype: int64

# %%
Fake_data.shape
# Out:
# (10000, 46)

# %%
Fake_data.isnull().sum()
# Out:
# Property_Title              0
# Address                     0
# Reviewed_Status             0
# Most_Recent_Status          0
# Source                      0
# Market                      0
# Occupancy                   0
# Flood                       1
# Street_Address              0
# City                        0
# State                       0
# Zip                         0
# Property_Type               0
# Highway                     0
# Train                       0
# Tax_Rate                    0
# SQFT_Basement               0
# HTW                         0
# Pool                        0
# Commercial                  0
# Water                       0
# Sewage                      0
# Year_Built                  0
# SQFT_MU                     0
# SQFT_Total                  0
# Parking                     0
# Bed                         0
# Bath                        0
# BasementYesNo               0
# Layout                      0
# Net_Yield                   0
# ...

# %%
property_df = Fake_data[['Property_Title', 'Source', 'Most_Recent_Status', 'Reviewed_Status']]
property_df
# Out:
#                                          Property_Title       Source  \
# 0     875 Davis Overpass Suite 394, South Kathrynsid...     Internal
# 1     1159 Johnson Pass Apt. 567, South Jamesfurt, M...  Auction.com
# 2     9082 Anna Villages Apt. 511, Port Juanshire, V...     Opendoor
# 3     86578 Lawson Park Suite 865, South Brianfurt, ...       M.L.S.
# 4          309 Roy Brook Apt. 282, Lake Scott, FL 84478       M.L.S.
# ...                                                 ...          ...
# 9995           139 Fisher Spur, North Brandon, WA 23114         Bulk
# 9996       275 Gutierrez Views, Lake Victoria, WY 63275        M L S
# 9997        341 Vanessa Harbor, North Melissa, CT 39313         Bulk
# 9998  78647 Brittany Village, North Ethanborough, NY...          MLS
# 9999  5461 Nichols Throughway, East Crystalborough, ...        M L S
#
#      Most_Recent_Status Reviewed_Status
# 0                Closed
# 1             Cancelled        Reviewed
# ...

# %%
location_df = Fake_data[['Address', 'Street_Address', 'City', 'State', 'Zip', 'Latitude', 'Longitude', 'Subdivision', 'Market']]

# %%
location_df
# Out:
#                                                 Address  \
# 0     875 Davis Overpass Suite 394, South Kathrynsid...
# 1     1159 Johnson Pass Apt. 567, South Jamesfurt, M...
# 2     9082 Anna Villages Apt. 511, Port Juanshire, V...
# 3     86578 Lawson Park Suite 865, South Brianfurt, ...
# 4          309 Roy Brook Apt. 282, Lake Scott, FL 84478
# ...                                                 ...
# 9995           139 Fisher Spur, North Brandon, WA 23114
# 9996       275 Gutierrez Views, Lake Victoria, WY 63275
# 9997        341 Vanessa Harbor, North Melissa, CT 39313
# 9998  78647 Brittany Village, North Ethanborough, NY...
# 9999  5461 Nichols Throughway, East Crystalborough, ...
#
#                     Street_Address                 City State    Zip  \
# 0     875 Davis Overpass Suite 394    South Kathrynside    CO  35116
# 1       1159 Johnson Pass Apt. 567      South Jamesfurt    MN  60391
# 2      9082 Anna Villages Apt. 511       Port Juanshire    VI  22393
# ...

# %%
property_features_df = Fake_data[['Property_Type', 'Occupancy', 'Year_Built', 'Layout', 'Bed', 'Bath', 'Pool', 'Commercial', 'Parking', 'SQFT_Total', 'SQFT_Basement', 'SQFT_MU', 'BasementYesNo']]

# %%
property_features_df
# Out:
#            Property_Type Occupancy  Year_Built    Layout  Bed  Bath Pool  \
# 0                    SFR       Yes        1921     Split    2     3   No
# 1     Single Family Home       Yes        1995  Colonial    2     2   No
# 2              Townhouse        No        1952     Ranch    5     2   No
# 3                 Duplex        No        1937     Ranch    1     2   No
# 4              Townhouse        No        1991     Split    5     4  Yes
# ...                  ...       ...         ...       ...  ...   ...  ...
# 9995  Single Family Home        No        2014  Colonial    4     4  Yes
# 9996              Duplex       Yes        2001  Colonial    2     2  Yes
# 9997  Single Family Home       Yes        2003     Split    2     3  Yes
# 9998  Single Family Home       Yes        2006     Split    1     3   No
# 9999  Single Family Home       Yes        1956  Colonial    4     1   No
#
#      Commercial   Parking  SQFT_Total  SQFT_Basement  SQFT_MU BasementYesNo
# ...

# %%
utility_df = Fake_data[['Flood', 'Highway', 'Train', 'Water', 'Sewage', 'HTW']]

# %%
utility_df
# Out:
#               Flood Highway Train Water  Sewage  HTW
# 0              None     Far  Near  Well    City  Yes
# 1     Minimal Flood     Far   Far  City  Septic  Yes
# 2        Flood Zone     Far  Near  City    City  Yes
# 3        Flood Zone    Near   Far  City    City   No
# 4        Flood Zone     Far  Near  City    City   No
# ...             ...     ...   ...   ...     ...  ...
# 9995     Flood Zone    Near  Near  Well  Septic  Yes
# 9996     Flood Zone    Near  Near  Well  Septic  Yes
# 9997     Flood Zone     Far  Near  Well  Septic  Yes
# 9998  Minimal Flood    Near  Near  City  Septic  Yes
# 9999     Flood Zone     Far   Far  Well  Septic   No
#
# [10000 rows x 6 columns]

# %%
financial_df = Fake_data[['Taxes', 'Tax_Rate', 'HOA', 'Rehab', 'Net_Yield', 'IRR', 'Valuation']]
financial_df
# Out:
#       Taxes  Tax_Rate                                                HOA  \
# 0      6389      2.95  [{'HOA': 460, 'HOA_Flag': 'No'}, {'HOA': 476, ...
# 1      9321      1.75  [{'HOA': 322, 'HOA_Flag': 'Yes'}, {'HOA': 219,...
# 2      9963      2.19  [{'HOA': 242, 'HOA_Flag': 'Yes'}, {'HOA': 470,...
# 3      2173      3.39                  [{'HOA': 500, 'HOA_Flag': 'Yes'}]
# 4      5985      2.20  [{'HOA': 197, 'HOA_Flag': 'Yes'}, {'HOA': 424,...
# ...     ...       ...                                                ...
# 9995   4822      3.34                   [{'HOA': 417, 'HOA_Flag': 'No'}]
# 9996   4850      3.18  [{'HOA': 103, 'HOA_Flag': 'No'}, {'HOA': 334, ...
# 9997   8370      2.94                                                 []
# 9998   9005      1.28  [{'HOA': 461, 'HOA_Flag': 'Yes'}, {'HOA': 469,...
# 9999   5199      3.39  [{'HOA': 18, 'HOA_Flag': 'No'}, {'HOA': 170, '...
#
#                                                   Rehab  Net_Yield    IRR  \
# ...

# %%
review_df = Fake_data[['Seller_Retained_Broker', 'Seller_Retained_Broker\t', 'Final_Reviewer', 'Selling_Reason']]
review_df
# Out:
#      Seller_Retained_Broker Seller_Retained_Broker\t   Final_Reviewer  \
# 0                       Yes                      Yes     Jason Miller
# 1                       Yes                      Yes      Luis Garcia
# 2                       Yes                      Yes  Samantha Pierce
# 3                       Yes                      Yes  Samantha Pierce
# 4                       Yes                      Yes     Priya Sharma
# ...                     ...                      ...              ...
# 9995                    Yes                      Yes   David Thompson
# 9996                    Yes                      Yes  Sophia Williams
# 9997                    Yes                      Yes     Jason Miller
# 9998                     No                      Yes  Samantha Pierce
# 9999                    Yes                      Yes      Emily Patel
#
#      Selling_Reason
# 0        Downsizing
# 1        Downsizing
# 2        Downsizing
# 3      Job Transfer
# ...

# %%
other_df = Fake_data[['Rent_Restricted', 'Neighborhood_Rating', 'School_Average']]
other_df
# Out:
#      Rent_Restricted  Neighborhood_Rating  School_Average
# 0                Yes                    2            9.09
# 1                Yes                    3            7.71
# 2                Yes                    3            6.04
# 3                Yes                    3            3.44
# 4                Yes                    2            9.01
# ...              ...                  ...             ...
# 9995             Yes                    5            3.08
# 9996              No                    4            9.88
# 9997              No                    4            7.74
# 9998              No                    1            6.62
# 9999              No                    3            3.73
#
# [10000 rows x 3 columns]

# %%
lead_col2 = Field_data.groupby('Target Table')['Column Name'].count()
lead_col2
# Out:
# Target Table
# HOA           2
# Leads         6
# Rehab        13
# Taxes         1
# Valuation     9
# leads         3
# property     32
# Name: Column Name, dtype: int64

# %%
property_df.to_csv("property.csv", index = False)

# %%
location_df.to_csv("location.csv", index = False)

# %%
property_features_df.to_csv("property_features_df.csv", index = False)

# %%
utility_df.to_csv("utility.csv", index = False)

# %%
financial_df.to_csv("financial.csv", index = False)

# %%
other_df.to_csv("others.csv", index = False)

# %%
# !pip install mysql
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.4/91.4 kB 475.0 kB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for mysqlclient: filename=mysqlclient-2.2.7-cp312-cp312-linux_x86_64.whl size=129064 sha256=109a48b980ba23c332517f103aa5f6b8acf1708de124bb180f832a6acbf67a79
#   Stored in directory: /root/.cache/pip/wheels/27/95/18/7f176fffd46629e710c04c810b9c4d7d4358fe7c96a7d2306d
# Successfully built mysqlclient
# ...
