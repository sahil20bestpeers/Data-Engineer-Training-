# %%
import pandas as pd
import numpy as np

# %%
courses  = pd.read_csv('/content/courses.csv')
courses
# Out:
#     course_id       course_name  price
# 0           1            python   2499
# 1           2               sql   3499
# 2           3     data analysis   4999
# 3           4  machine learning   9999
# 4           5           tableau   2499
# 5           6          power bi   1899
# 6           7          ms sxcel   1599
# 7           8            pandas   1099
# 8           9            plotly    699
# 9          10           pyspark   2499
# 10         11             Numpy    699
# 11         12               C++   1299

# %%
student1 = pd.read_csv('/content/reg-month2.csv')
student1
# Out:
#     student_id  course_id
# 0            3          5
# 1           16          7
# 2           12         10
# 3           12          1
# 4           14          9
# 5            7          7
# 6            7          2
# 7           16          3
# 8           17         10
# 9           11          8
# 10          14          6
# 11          12          5
# 12          12          7
# 13          18          8
# 14           1         10
# 15           1          9
# 16           2          5
# 17           7          6
# 18          22          5
# 19          22          6
# 20          23          9
# 21          23          5
# 22          14          4
# 23          14          1
# 24          11         10
# 25          42          9
# 26          50          8
# 27          38          1

# %%
students2 = pd.read_csv('/content/reg-month2.csv')
students2
# Out:
#     student_id  course_id
# 0            3          5
# 1           16          7
# 2           12         10
# 3           12          1
# 4           14          9
# 5            7          7
# 6            7          2
# 7           16          3
# 8           17         10
# 9           11          8
# 10          14          6
# 11          12          5
# 12          12          7
# 13          18          8
# 14           1         10
# 15           1          9
# 16           2          5
# 17           7          6
# 18          22          5
# 19          22          6
# 20          23          9
# 21          23          5
# 22          14          4
# 23          14          1
# 24          11         10
# 25          42          9
# 26          50          8
# 27          38          1

# %%
merged_table = pd.merge(student1,students2)
merged_table
# Out:
#     student_id  course_id
# 0            3          5
# 1           16          7
# 2           12         10
# 3           12          1
# 4           14          9
# 5            7          7
# 6            7          2
# 7           16          3
# 8           17         10
# 9           11          8
# 10          14          6
# 11          12          5
# 12          12          7
# 13          18          8
# 14           1         10
# 15           1          9
# 16           2          5
# 17           7          6
# 18          22          5
# 19          22          6
# 20          23          9
# 21          23          5
# 22          14          4
# 23          14          1
# 24          11         10
# 25          42          9
# 26          50          8
# 27          38          1

# %%
concated_table = pd.merge(merged_table,courses)
concated_table
# Out:
#     student_id  course_id       course_name  price
# 0            3          5           tableau   2499
# 1           16          7          ms sxcel   1599
# 2           12         10           pyspark   2499
# 3           12          1            python   2499
# 4           14          9            plotly    699
# 5            7          7          ms sxcel   1599
# 6            7          2               sql   3499
# 7           16          3     data analysis   4999
# 8           17         10           pyspark   2499
# 9           11          8            pandas   1099
# 10          14          6          power bi   1899
# 11          12          5           tableau   2499
# 12          12          7          ms sxcel   1599
# 13          18          8            pandas   1099
# 14           1         10           pyspark   2499
# 15           1          9            plotly    699
# 16           2          5           tableau   2499
# ...

# %%
enrolled_students = concated_table.groupby('course_name')['student_id'].sum()
enrolled_students
# Out:
# course_name
# data analysis       16
# machine learning    14
# ms sxcel            35
# pandas              79
# plotly              80
# power bi            43
# pyspark             41
# python              64
# sql                  7
# tableau             62
# Name: student_id, dtype: int64

# %%
courses_renamed = courses.rename(columns={'course_id': 'course_id_courses'},inplace = True)

# %%
courses
# Out:
#     student_id_left  course_id_courses  student_id_right  course_id_left  \
# 0                 3                  5                 7               7
# 1                16                  7                16               3
# 2                12                 10                14               6
# 3                12                  1                16               7
# 4                14                  9                11               8
# 5                 7                  7                16               3
# 6                 7                  2                12              10
# 7                16                  3                12               1
# 8                17                 10                14               6
# 9                11                  8                17              10
# 10               14                  6                 7               2
# 11               12                  5                 7               7
# ...
