# %%
import numpy as np
import pandas as pd

# %%
courses = pd.read_csv("/content/courses.csv")
deliveries =  pd.read_csv("/content/deliveries (3).csv")
matches = pd.read_csv('/content/matches.csv')
nov = pd.read_csv('/content/reg-month1.csv')
dec = pd.read_csv('/content/reg-month2.csv')
students = pd.read_csv('/content/students (1).csv')

# %%
print(type(nov))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data = pd.DataFrame(nov)
data
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3

# %%
courses
# Out:
#     course_id       course_name  price
# 0           1            python   2499
# 1           2               sql   3499
# 2           3     data analysis   4999
# 3           4  machine learning   9999
# 4           5           tableau   2499
# 5           6          power bi   1899
# 6           7          ms sxcel   1599
# 7           8            pandas   1099
# 8           9            plotly    699
# 9          10           pyspark   2499
# 10         11             Numpy    699
# 11         12               C++   1299

# %%
students
# Out:
#     student_id                name  partner
# 0            1       Kailash Harjo       23
# 1            2         Esha Butala        1
# 2            3      Parveen Bhalla        3
# 3            4         Marlo Dugal       14
# 4            5         Kusum Bahri        6
# 5            6  Lakshmi Contractor       10
# 6            7        Tarun Thaker        9
# 7            8      Radheshyam Dey        5
# 8            9   Nitika Chatterjee        4
# 9           10      Aayushman Sant        8
# 10          11  David Mukhopadhyay       20
# 11          12          Radha Dutt       19
# 12          13      Munni Varghese       24
# 13          14    Pranab Natarajan       22
# 14          15           Preet Sha       16
# 15          16        Elias Dodiya       25
# 16          17        Yasmin Palan        7
# 17          18     Fardeen Mahabir       13
# 18          19        Qabeel Raman       12
# 19          20       Hanuman Hegde       11
# ...

# %%
nov.shape
# Out:
# (25, 2)

# %%
regs = pd.concat([nov,dec],axis = 1, keys =['NovemberData','DecemberData'])
regs
# Out:
#    NovemberData           DecemberData
#      student_id course_id   student_id course_id
# 0          23.0       1.0            3         5
# 1          15.0       5.0           16         7
# 2          18.0       6.0           12        10
# 3          23.0       4.0           12         1
# 4          16.0       9.0           14         9
# 5          18.0       1.0            7         7
# 6           1.0       1.0            7         2
# 7           7.0       8.0           16         3
# 8          22.0       3.0           17        10
# 9          15.0       1.0           11         8
# 10         19.0       4.0           14         6
# 11          1.0       6.0           12         5
# 12          7.0      10.0           12         7
# 13         11.0       7.0           18         8
# 14         13.0       3.0            1        10
# 15         24.0       4.0            1         9
# 16         21.0       1.0            2         5
# ...

# %%
multi = pd.concat([nov,dec],keys = ['nov','Dec'])
multi
# Out:
#         student_id  course_id
# nov 0           23          1
#     1           15          5
#     2           18          6
#     3           23          4
#     4           16          9
#     5           18          1
#     6            1          1
#     7            7          8
#     8           22          3
#     9           15          1
#     10          19          4
#     11           1          6
#     12           7         10
#     13          11          7
#     14          13          3
#     15          24          4
#     16          21          1
#     17          16          5
#     18          23          3
#     19          17          7
#     20          23          6
#     21          25          1
#     22          19          2
#     23          25         10
#     24           3          3
# Dec 0            3          5
#     1           16          7
#     2           12         10
#     3           12          1
#     4           14          9
# ...

# %%
multi.loc[('nov',0)]
# Out:
# student_id    23
# course_id      1
# Name: (nov, 0), dtype: int64

# %%
regs
# Out:
#    NovemberData           DecemberData
#      student_id course_id   student_id course_id
# 0          23.0       1.0            3         5
# 1          15.0       5.0           16         7
# 2          18.0       6.0           12        10
# 3          23.0       4.0           12         1
# 4          16.0       9.0           14         9
# 5          18.0       1.0            7         7
# 6           1.0       1.0            7         2
# 7           7.0       8.0           16         3
# 8          22.0       3.0           17        10
# 9          15.0       1.0           11         8
# 10         19.0       4.0           14         6
# 11          1.0       6.0           12         5
# 12          7.0      10.0           12         7
# 13         11.0       7.0           18         8
# 14         13.0       3.0            1        10
# 15         24.0       4.0            1         9
# 16         21.0       1.0            2         5
# ...

# %%
temp_df = pd.DataFrame({
    'student_id':[26,27,28],
    'name':['Nitish','Ankit','Rahul'],
    'Partner':[28,26,17]
})

students = pd.concat([students,temp_df],ignore_index = True)
students
# Out:
#     student_id                name  partner  Partner
# 0            1       Kailash Harjo     23.0      NaN
# 1            2         Esha Butala      1.0      NaN
# 2            3      Parveen Bhalla      3.0      NaN
# 3            4         Marlo Dugal     14.0      NaN
# 4            5         Kusum Bahri      6.0      NaN
# 5            6  Lakshmi Contractor     10.0      NaN
# 6            7        Tarun Thaker      9.0      NaN
# 7            8      Radheshyam Dey      5.0      NaN
# 8            9   Nitika Chatterjee      4.0      NaN
# 9           10      Aayushman Sant      8.0      NaN
# 10          11  David Mukhopadhyay     20.0      NaN
# 11          12          Radha Dutt     19.0      NaN
# 12          13      Munni Varghese     24.0      NaN
# 13          14    Pranab Natarajan     22.0      NaN
# 14          15           Preet Sha     16.0      NaN
# 15          16        Elias Dodiya     25.0      NaN
# 16          17        Yasmin Palan      7.0      NaN
# ...

# %%
left = pd.DataFrame(
    {
        "key": ["K0", "K1", "K2", "K3"],
        "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
    }
)


right = pd.DataFrame(
    {
        "key": ["K0", "K1", "K2", "K3"],
        "C": ["C0", "C1", "C2", "C3"],
        "D": ["D0", "D1", "D2", "D3"],
    }
)


result = pd.merge(left, right, on="key")
result
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
df1 = pd.DataFrame({"col1": [0, 1], "col_left": ["a", "b"]})

df2 = pd.DataFrame({"col1": [1, 2, 2], "col_right": [2, 2, 2]})

pd.merge(df1, df2, on="col1", how="outer", indicator=True)
# Out:
#    col1 col_left  col_right      _merge
# 0     0        a        NaN   left_only
# 1     1        b        2.0        both
# 2     2      NaN        2.0  right_only
# 3     2      NaN        2.0  right_only

# %%
left = pd.DataFrame({"k": ["K0", "K1", "K2"], "v": [1, 2, 3]})

right = pd.DataFrame({"k": ["K0", "K0", "K3"], "v": [4, 5, 6]})

result = pd.merge(left, right, on="k")

result
# Out:
#     k  v_x  v_y
# 0  K0    1    4
# 1  K0    1    5

# %%
left = pd.DataFrame(
    {"A": ["A0", "A1", "A2"], "B": ["B0", "B1", "B2"]}, index=["K0", "K1", "K2"]
)


right = pd.DataFrame(
    {"C": ["C0", "C2", "C3"], "D": ["D0", "D2", "D3"]}, index=["K0", "K2", "K3"]
)


result = left.join(right)

result
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2

# %%
df1 = pd.DataFrame({'lkey': ['foo', 'bar', 'baz', 'foo'],
                    'value': [1, 2, 3, 5]})
df2 = pd.DataFrame({'rkey': ['foo', 'bar', 'baz', 'foo'],
                    'value': [5, 6, 7, 8]})
df1
# Out:
#   lkey  value
# 0  foo      1
# 1  bar      2
# 2  baz      3
# 3  foo      5

# %%
df1.merge(df2, left_on='lkey', right_on='rkey')
# Out:
#   lkey  value_x rkey  value_y
# 0  foo        1  foo        5
# 1  foo        1  foo        8
# 2  bar        2  bar        6
# 3  baz        3  baz        7
# 4  foo        5  foo        5
# 5  foo        5  foo        8

# %%
df1.merge(df2, left_on='lkey', right_on='rkey',
          suffixes=('_left', '_right'))
# Out:
#   lkey  value_left rkey  value_right
# 0  foo           1  foo            5
# 1  foo           1  foo            8
# 2  bar           2  bar            6
# 3  baz           3  baz            7
# 4  foo           5  foo            5
# 5  foo           5  foo            8

# %%
df1 = pd.DataFrame({'left': ['foo', 'bar']})
df2 = pd.DataFrame({'right': [7, 8]})
df1
# Out:
#   left
# 0  foo
# 1  bar

# %%
df1.merge(df2, how='cross')
# Out:
#   left  right
# 0  foo      7
# 1  foo      8
# 2  bar      7
# 3  bar      8

# %%
df1
# Out:
#   left
# 0  foo
# 1  bar

# %%
s1 = pd.Series(['a', 'b'])
s2 = pd.Series(['c', 'd'])
pd.concat([s1, s2])
# Out:
# 0    a
# 1    b
# 0    c
# 1    d
# dtype: object

# %%
pd.concat([s1, s2], ignore_index=True)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
pd.concat([s1, s2], keys=['s1', 's2'])
# Out:
# s1  0    a
#     1    b
# s2  0    c
#     1    d
# dtype: object

# %%
pd.concat([s1, s2], keys=['s1', 's2'],
          names=['Series name', 'Row ID'])
# Out:
# Series name  Row ID
# s1           0         a
#              1         b
# s2           0         c
#              1         d
# dtype: object

# %%
df1 = pd.DataFrame([['a', 1], ['b', 2]],
                   columns=['letter', 'number'])
df1
# Out:
#   letter  number
# 0      a       1
# 1      b       2

# %%
df2 = pd.DataFrame([['c', 3], ['d', 4]],
                   columns=['letter', 'number'])
df2
# Out:
#   letter  number
# 0      c       3
# 1      d       4

# %%
pd.concat([df1, df2])
# Out:
#   letter  number
# 0      a       1
# 1      b       2
# 0      c       3
# 1      d       4

# %%
df4 = pd.DataFrame([['bird', 'polly'], ['monkey', 'george']],
                   columns=['animal', 'name'])
pd.concat([df1, df4], axis=1)
# Out:
#   letter  number  animal    name
# 0      a       1    bird   polly
# 1      b       2  monkey  george

# %%
df5 = pd.DataFrame([1], index=['a'])
df5
# Out:
#    0
# a  1

# %%
df7 = pd.DataFrame({'a': 1, 'b': 2}, index=[0])
df7
# Out:
#    a  b
# 0  1  2

# %%
new_row = pd.Series({'a': 3, 'b': 4})
new_row
# Out:
# a    3
# b    4
# dtype: int64

# %%
pd.concat([df7, new_row.to_frame().T], ignore_index=True)
# Out:
#    a  b
# 0  1  2
# 1  3  4

# %%
df = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3', 'K4', 'K5'],
                   'A': ['A0', 'A1', 'A2', 'A3', 'A4', 'A5']})

# %%
other = pd.DataFrame({'key': ['K0', 'K1', 'K2'],
                      'B': ['B0', 'B1', 'B2']})

# %%
df = pd.DataFrame({'key': ['K0', 'K1', 'K1', 'K3', 'K0', 'K1'],
                   'A': ['A0', 'A1', 'A2', 'A3', 'A4', 'A5']})

# %%
df.join(other.set_index('key'), on='key', validate='m:1')
# Out:
#   key   A    B
# 0  K0  A0   B0
# 1  K1  A1   B1
# 2  K1  A2   B1
# 3  K3  A3  NaN
# 4  K0  A4   B0
# 5  K1  A5   B1

# %%
df = pd.read_csv('/content/matches.csv')
df
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
df.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              1
# umpire2              1
# umpire3            636
# dtype: int64

# %%
df['city']
# Out:
# 0      Hyderabad
# 1           Pune
# 2         Rajkot
# 3         Indore
# 4      Bangalore
#          ...
# 631       Raipur
# 632    Bangalore
# 633        Delhi
# 634        Delhi
# 635    Bangalore
# Name: city, Length: 636, dtype: object

# %%
df['city'].value_counts()
# Out:
# city
# Mumbai            85
# Bangalore         66
# Kolkata           61
# Delhi             60
# Hyderabad         49
# Chennai           48
# Chandigarh        46
# Jaipur            33
# Pune              32
# Durban            15
# Centurion         12
# Ahmedabad         12
# Visakhapatnam     11
# Rajkot            10
# Dharamsala         9
# Johannesburg       8
# Cape Town          7
# Port Elizabeth     7
# Ranchi             7
# Abu Dhabi          7
# Cuttack            7
# Raipur             6
# Sharjah            6
# Indore             5
# Kochi              5
# Kanpur             4
# East London        3
# Kimberley          3
# Nagpur             3
# Bloemfontein       2
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# id                   int64
# season               int64
# city                object
# date                object
# team1               object
# team2               object
# toss_winner         object
# toss_decision       object
# result              object
# dl_applied           int64
# winner              object
# win_by_runs          int64
# win_by_wickets       int64
# player_of_match     object
# venue               object
# umpire1             object
# umpire2             object
# umpire3            float64
# dtype: object

# %%
df.drop_duplicates()
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
# combining Data From multiple sources
air_quality_pm25 = pd.read_csv("/content/courses.csv",
                               parse_dates=True)

air_quality_pm25 = air_quality_pm25[['course_id','course_name','price']]
air_quality_no2 = pd.read_csv("/content/students (1).csv",
                              parse_dates=True)

air_quality_pm25.head()
# Out:
#    course_id       course_name  price
# 0          1            python   2499
# 1          2               sql   3499
# 2          3     data analysis   4999
# 3          4  machine learning   9999
# 4          5           tableau   2499

# %%
courses
# Out:
#     course_id       course_name  price
# 0           1            python   2499
# 1           2               sql   3499
# 2           3     data analysis   4999
# 3           4  machine learning   9999
# 4           5           tableau   2499
# 5           6          power bi   1899
# 6           7          ms sxcel   1599
# 7           8            pandas   1099
# 8           9            plotly    699
# 9          10           pyspark   2499
# 10         11             Numpy    699
# 11         12               C++   1299

# %%
students = pd.read_csv('/content/students (1).csv')
students



students = students[['student_id','name','partner']]

# %%
nov
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3

# %%
dec
# Out:
#     student_id  course_id
# 0            3          5
# 1           16          7
# 2           12         10
# 3           12          1
# 4           14          9
# 5            7          7
# 6            7          2
# 7           16          3
# 8           17         10
# 9           11          8
# 10          14          6
# 11          12          5
# 12          12          7
# 13          18          8
# 14           1         10
# 15           1          9
# 16           2          5
# 17           7          6
# 18          22          5
# 19          22          6
# 20          23          9
# 21          23          5
# 22          14          4
# 23          14          1
# 24          11         10
# 25          42          9
# 26          50          8
# 27          38          1

# %%
students
# Out:
#     student_id                name  partner
# 0            1       Kailash Harjo       23
# 1            2         Esha Butala        1
# 2            3      Parveen Bhalla        3
# 3            4         Marlo Dugal       14
# 4            5         Kusum Bahri        6
# 5            6  Lakshmi Contractor       10
# 6            7        Tarun Thaker        9
# 7            8      Radheshyam Dey        5
# 8            9   Nitika Chatterjee        4
# 9           10      Aayushman Sant        8
# 10          11  David Mukhopadhyay       20
# 11          12          Radha Dutt       19
# 12          13      Munni Varghese       24
# 13          14    Pranab Natarajan       22
# 14          15           Preet Sha       16
# 15          16        Elias Dodiya       25
# 16          17        Yasmin Palan        7
# 17          18     Fardeen Mahabir       13
# 18          19        Qabeel Raman       12
# 19          20       Hanuman Hegde       11
# ...

# %%
df = pd.concat([courses,students],axis = 0)
df
# Out:
#     course_id       course_name   price  student_id                name  \
# 0         1.0            python  2499.0         NaN                 NaN
# 1         2.0               sql  3499.0         NaN                 NaN
# 2         3.0     data analysis  4999.0         NaN                 NaN
# 3         4.0  machine learning  9999.0         NaN                 NaN
# 4         5.0           tableau  2499.0         NaN                 NaN
# 5         6.0          power bi  1899.0         NaN                 NaN
# 6         7.0          ms sxcel  1599.0         NaN                 NaN
# 7         8.0            pandas  1099.0         NaN                 NaN
# 8         9.0            plotly   699.0         NaN                 NaN
# 9        10.0           pyspark  2499.0         NaN                 NaN
# 10       11.0             Numpy   699.0         NaN                 NaN
# 11       12.0               C++  1299.0         NaN                 NaN
# ...

# %%
# Exercise 17:
# Merge two DataFrames:
# sales.csv: Contains store_id, date, sales
# weather.csv: Contains store_id, date, temperature
# Join on store_id and date. Then analyze how temperature affects sales.

# %%
weather_data = {
    'day':['January',' February', 'March',' April',' May',' June',' July',' August',' September','october','november','december'],
    'Temperature': [20, 22, 28,30,35,40,32,30,25,25,22,21],
    'weather':['Verycold',' cold','normal','Hot']
}

# %%
courses
# Out:
#     course_id       course_name  price
# 0           1            python   2499
# 1           2               sql   3499
# 2           3     data analysis   4999
# 3           4  machine learning   9999
# 4           5           tableau   2499
# 5           6          power bi   1899
# 6           7          ms sxcel   1599
# 7           8            pandas   1099
# 8           9            plotly    699
# 9          10           pyspark   2499
# 10         11             Numpy    699
# 11         12               C++   1299

# %%
students
# Out:
#     student_id                name  partner
# 0            1       Kailash Harjo       23
# 1            2         Esha Butala        1
# 2            3      Parveen Bhalla        3
# 3            4         Marlo Dugal       14
# 4            5         Kusum Bahri        6
# 5            6  Lakshmi Contractor       10
# 6            7        Tarun Thaker        9
# 7            8      Radheshyam Dey        5
# 8            9   Nitika Chatterjee        4
# 9           10      Aayushman Sant        8
# 10          11  David Mukhopadhyay       20
# 11          12          Radha Dutt       19
# 12          13      Munni Varghese       24
# 13          14    Pranab Natarajan       22
# 14          15           Preet Sha       16
# 15          16        Elias Dodiya       25
# 16          17        Yasmin Palan        7
# 17          18     Fardeen Mahabir       13
# 18          19        Qabeel Raman       12
# 19          20       Hanuman Hegde       11
# ...

# %%
courses
# Out:
#     course_id       course_name  price
# 0           1            python   2499
# 1           2               sql   3499
# 2           3     data analysis   4999
# 3           4  machine learning   9999
# 4           5           tableau   2499
# 5           6          power bi   1899
# 6           7          ms sxcel   1599
# 7           8            pandas   1099
# 8           9            plotly    699
# 9          10           pyspark   2499
# 10         11             Numpy    699
# 11         12               C++   1299

# %%
courses = pd.DataFrame(courses)

# %%
courses
# Out:
#     course_id       course_name  price
# 0           1            python   2499
# 1           2               sql   3499
# 2           3     data analysis   4999
# 3           4  machine learning   9999
# 4           5           tableau   2499
# 5           6          power bi   1899
# 6           7          ms sxcel   1599
# 7           8            pandas   1099
# 8           9            plotly    699
# 9          10           pyspark   2499
# 10         11             Numpy    699
# 11         12               C++   1299

# %%
nov
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3

# %%
nov
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3

# %%
students
# Out:
#     student_id                name  partner
# 0            1       Kailash Harjo       23
# 1            2         Esha Butala        1
# 2            3      Parveen Bhalla        3
# 3            4         Marlo Dugal       14
# 4            5         Kusum Bahri        6
# 5            6  Lakshmi Contractor       10
# 6            7        Tarun Thaker        9
# 7            8      Radheshyam Dey        5
# 8            9   Nitika Chatterjee        4
# 9           10      Aayushman Sant        8
# 10          11  David Mukhopadhyay       20
# 11          12          Radha Dutt       19
# 12          13      Munni Varghese       24
# 13          14    Pranab Natarajan       22
# 14          15           Preet Sha       16
# 15          16        Elias Dodiya       25
# 16          17        Yasmin Palan        7
# 17          18     Fardeen Mahabir       13
# 18          19        Qabeel Raman       12
# 19          20       Hanuman Hegde       11
# ...
